# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd '/content/drive/MyDrive/Hong/'
# Out:
# /content/drive/MyDrive/Hong

# %%
ls
# Out:
# 'EDA + Model .ipynb'   Photo/   top_insta_influencers_data.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install seaborn --upgrade
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Collecting seaborn
#   Downloading seaborn-0.13.0-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# Installing collected packages: seaborn
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
#       Successfully uninstalled seaborn-0.12.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# Successfully installed seaborn-0.13.0

# %%
df=pd.read_csv('top_insta_influencers_data.csv')

# %%
df.head()
# Out:
#    rank channel_info  influence_score  posts  followers  avg_likes  \
# 0     1    cristiano               92   3.30      475.8        8.7
# 1     2  kyliejenner               91   6.90      366.2        8.3
# 2     3     leomessi               90   0.89      357.3        6.8
# 3     4  selenagomez               93   1.80      342.7        6.2
# 4     5      therock               91   6.80      334.1        1.9
#
#    60_day_eng_rate  new_post_avg_like  total_likes        country  posts(k)  \
# 0             1.39                6.5         29.0          Spain      3.30
# 1             1.62                5.9         57.4  United States      6.90
# 2             1.24                4.4          6.0          Other      0.89
# 3             0.97                3.3         11.5  United States      1.80
# 4             0.20              665.3         12.5  United States      6.80
#
#    followers(m)  avg_likes(m)  new_post_avg_like(m)  total_likes(b)
# 0         475.8           8.7                   6.5            29.0
# 1         366.2           8.3                   5.9            57.4
# 2         357.3           6.8                   4.4             6.0
# 3         342.7           6.2                   3.3            11.5
# 4         334.1           1.9                 665.3            12.5
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_21['rank'].plot(kind='hist', bins=20, title='rank')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_22['influence_score'].plot(kind='hist', bins=20, title='influence_score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_23['posts'].plot(kind='hist', bins=20, title='posts')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_24['followers'].plot(kind='hist', bins=20, title='followers')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_25.groupby('channel_info').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_26.groupby('country').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_27.plot(kind='scatter', x='rank', y='influence_score', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_28.plot(kind='scatter', x='influence_score', y='posts', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_29.plot(kind='scatter', x='posts', y='followers', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_30.plot(kind='scatter', x='followers', y='avg_likes', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['rank']
#   ys = series['influence_score']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_31.sort_values('rank', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('channel_info')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='channel_info', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('rank')
# _ = plt.ylabel('influence_score')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['rank']
#   ys = series['influence_score']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_32.sort_values('rank', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('country')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='country', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('rank')
# _ = plt.ylabel('influence_score')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['rank']
#   ys = series['posts']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_33.sort_values('rank', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('channel_info')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='channel_info', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('rank')
# _ = plt.ylabel('posts')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['rank']
#   ys = series['posts']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_34.sort_values('rank', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('country')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='country', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('rank')
# _ = plt.ylabel('posts')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_35['rank'].plot(kind='line', figsize=(8, 4), title='rank')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_36['influence_score'].plot(kind='line', figsize=(8, 4), title='influence_score')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_37['posts'].plot(kind='line', figsize=(8, 4), title='posts')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_38['followers'].plot(kind='line', figsize=(8, 4), title='followers')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['country'].value_counts()
#     for x_label, grp in _df_39.groupby('channel_info')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('channel_info')
# _ = plt.ylabel('country')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_40['channel_info'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_40, x='rank', y='channel_info', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_41['country'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_41, x='rank', y='country', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_42['channel_info'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_42, x='influence_score', y='channel_info', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_43['country'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_43, x='influence_score', y='country', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df.shape
# Out:
# (200, 10)

# %%
df.dtypes
# Out:
# rank                  int64
# channel_info         object
# influence_score       int64
# posts                object
# followers            object
# avg_likes            object
# 60_day_eng_rate      object
# new_post_avg_like    object
# total_likes          object
# country              object
# dtype: object

# %%
df["posts"]= df["posts"].str[:-1]
df["followers"]= df["followers"].str[:-1]
df["avg_likes"]= df["avg_likes"].str[:-1]
df["60_day_eng_rate"]= df["60_day_eng_rate"].str[:-1]
df["new_post_avg_like"]= df["new_post_avg_like"].str[:-1]
df["total_likes"]= df["total_likes"].str[:-1]

# %%
df["posts"]= pd.to_numeric(df["posts"],errors='coerce')
df["followers"]= pd.to_numeric(df["followers"],errors='coerce')
df["avg_likes"]= pd.to_numeric(df["avg_likes"],errors='coerce')
df["60_day_eng_rate"]= pd.to_numeric(df["60_day_eng_rate"],errors='coerce')
df["new_post_avg_like"]= pd.to_numeric(df["new_post_avg_like"],errors='coerce')
df["total_likes"]= pd.to_numeric(df["total_likes"],errors='coerce')

# %%
df["posts(k)"]= df["posts"]
df["followers(m)"]= df["followers"]
df["avg_likes(m)"]= df["avg_likes"]
df["new_post_avg_like(m)"]= df["new_post_avg_like"]
df["total_likes(b)"]= df["total_likes"]

# %%
df.head()
# Out:
#    rank channel_info  influence_score  posts  followers  avg_likes  \
# 0     1    cristiano               92   3.30      475.8        8.7
# 1     2  kyliejenner               91   6.90      366.2        8.3
# 2     3     leomessi               90   0.89      357.3        6.8
# 3     4  selenagomez               93   1.80      342.7        6.2
# 4     5      therock               91   6.80      334.1        1.9
#
#    60_day_eng_rate  new_post_avg_like  total_likes        country  posts(k)  \
# 0             1.39                6.5         29.0          Spain      3.30
# 1             1.62                5.9         57.4  United States      6.90
# 2             1.24                4.4          6.0            NaN      0.89
# 3             0.97                3.3         11.5  United States      1.80
# 4             0.20              665.3         12.5  United States      6.80
#
#    followers(m)  avg_likes(m)  new_post_avg_like(m)  total_likes(b)
# 0         475.8           8.7                   6.5            29.0
# 1         366.2           8.3                   5.9            57.4
# 2         357.3           6.8                   4.4             6.0
# 3         342.7           6.2                   3.3            11.5
# 4         334.1           1.9                 665.3            12.5

# %%
df.isnull().sum()
# Out:
# rank                     0
# channel_info             0
# influence_score          0
# posts                    0
# followers                0
# avg_likes                0
# 60_day_eng_rate          1
# new_post_avg_like        8
# total_likes              0
# country                 62
# posts(k)                 0
# followers(m)             0
# avg_likes(m)             0
# new_post_avg_like(m)     8
# total_likes(b)           0
# dtype: int64

# %%
df['country'].fillna('Other', inplace=True)

# %%
clean_df = df[["rank",'channel_info','influence_score','posts(k)','followers(m)','avg_likes(m)','60_day_eng_rate','new_post_avg_like(m)','total_likes(b)','country']]
clean_df.head()
# Out:
#    rank channel_info  influence_score  posts(k)  followers(m)  avg_likes(m)  \
# 0     1    cristiano               92      3.30         475.8           8.7
# 1     2  kyliejenner               91      6.90         366.2           8.3
# 2     3     leomessi               90      0.89         357.3           6.8
# 3     4  selenagomez               93      1.80         342.7           6.2
# 4     5      therock               91      6.80         334.1           1.9
#
#    60_day_eng_rate  new_post_avg_like(m)  total_likes(b)        country
# 0             1.39                   6.5            29.0          Spain
# 1             1.62                   5.9            57.4  United States
# 2             1.24                   4.4             6.0          Other
# 3             0.97                   3.3            11.5  United States
# 4             0.20                 665.3            12.5  United States

# %%
chart_df = clean_df.head(10)
sns.set_theme(style="whitegrid")
ax = sns.barplot(chart_df, x="followers(m)", y="channel_info")
ax.bar_label(ax.containers[0], fontsize=10);

# %%
chart_df = clean_df.sort_values(by=["influence_score"], ascending=False)
sns.set_theme(style="whitegrid")
ax = sns.barplot(chart_df.head(10), x="influence_score", y="channel_info")
ax.bar_label(ax.containers[0], fontsize=10);

# %%
plt.figure(figsize=(20, 6))
sns.boxplot(data=clean_df, x="total_likes(b)", y="country")
# Out:
# <Axes: xlabel='total_likes(b)', ylabel='country'>

# %%
avg_likes_country = clean_df.groupby(['country'],as_index=False).mean()
plt.figure(figsize=(20, 6))
ax = sns.barplot(data=avg_likes_country, x="total_likes(b)", y="country")
ax.bar_label(ax.containers[0], fontsize=10);
# Out:
# <ipython-input-19-ae0fd2687151>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_likes_country = clean_df.groupby(['country'],as_index=False).mean()

# %%
no_inf_country = clean_df.groupby("country",as_index= False).count()
plt.figure(figsize=(20, 6))
ax = sns.barplot(data=no_inf_country, x="rank", y="country")
ax.bar_label(ax.containers[0], fontsize=10);

# %%
no_inf_country = no_inf_country[["country",'rank']]
no_inf_country['percentage(%)'] = 0
no_inf_country['percentage(%)'] = (no_inf_country['rank']/len(clean_df))*100
percent = no_inf_country['percentage(%)'].to_numpy()
country = no_inf_country['country'].to_numpy()
palette_color = sns.color_palette('bright')
plt.figure(figsize=(20, 20))
plt.pie(percent, labels=country, colors=palette_color, autopct='%.0f%%')
# Out:
# <ipython-input-21-86e2cdb93080>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_inf_country['percentage(%)'] = 0
# <ipython-input-21-86e2cdb93080>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_inf_country['percentage(%)'] = (no_inf_country['rank']/len(clean_df))*100
# ([<matplotlib.patches.Wedge at 0x7e1b06e948e0>,
#   <matplotlib.patches.Wedge at 0x7e1b06e94820>,
#   <matplotlib.patches.Wedge at 0x7e1b06e95210>,
#   <matplotlib.patches.Wedge at 0x7e1b06e958a0>,
#   <matplotlib.patches.Wedge at 0x7e1b06e95f30>,
#   <matplotlib.patches.Wedge at 0x7e1b06e965c0>,
#   <matplotlib.patches.Wedge at 0x7e1b06e96c50>,
#   <matplotlib.patches.Wedge at 0x7e1b06e972e0>,
#   <matplotlib.patches.Wedge at 0x7e1b06e97970>,
#   <matplotlib.patches.Wedge at 0x7e1b06ed8040>,
#   <matplotlib.patches.Wedge at 0x7e1b06e947f0>,
#   <matplotlib.patches.Wedge at 0x7e1b06ed8d30>,
#   <matplotlib.patches.Wedge at 0x7e1b06ed93c0>,
#   <matplotlib.patches.Wedge at 0x7e1b06ed9a50>,
#   <matplotlib.patches.Wedge at 0x7e1b0711b0a0>,
#   <matplotlib.patches.Wedge at 0x7e1b06eda5c0>,
#   <matplotlib.patches.Wedge at 0x7e1b06edac50>,
#   <matplotlib.patches.Wedge at 0x7e1b06edb2e0>,
#   <matplotlib.patches.Wedge at 0x7e1b06edb970>,
#   <matplotlib.patches.Wedge at 0x7e1b06f14040>,
#   <matplotlib.patches.Wedge at 0x7e1b06f146d0>,
#   <matplotlib.patches.Wedge at 0x7e1b06f14d60>,
#   <matplotlib.patches.Wedge at 0x7e1b06f153f0>,
#   <matplotlib.patches.Wedge at 0x7e1b06f15a80>,
#   <matplotlib.patches.Wedge at 0x7e1b06f16110>,
#   <matplotlib.patches.Wedge at 0x7e1b06f167a0>],
#  [Text(1.099864295735893, 0.017278048656840017, 'Anguilla'),
#   Text(1.098778862512746, 0.05181709462326203, 'Australia'),
#   Text(1.0610131628853108, 0.29026034552468416, 'Brazil'),
#   Text(0.9721422017118516, 0.51472277941707, 'British Virgin Islands'),
#   Text(0.9379041912155436, 0.5747484041737891, 'Canada'),
#   Text(0.8796531377080374, 0.6604622300483236, 'Colombia'),
#   Text(0.8364465776274876, 0.7143928350531404, 'Czech Republic'),
#   Text(0.8135942210249916, 0.7403137466741634, "CÃ´te d'Ivoire"),
#   Text(0.727443072328198, 0.8251221585448498, 'France'),
#   Text(0.6325058017885571, 0.8999646719198564, 'Germany'),
#   Text(0.43686271183472813, 1.0095300743456865, 'India'),
#   Text(0.12070778109979041, 1.0933570467061369, 'Indonesia'),
#   Text(-0.01727801004056712, 1.0998642963425254, 'Italy'),
#   Text(-0.0690695313956241, 1.0978294037931344, 'Mexico'),
#   Text(-0.13786651553891577, 1.0913261766736644, 'Netherlands'),
#   Text(-0.9953097431322409, 0.4683572517064651, 'Other'),
#   Text(-0.9379041945787829, -0.574748398685481, 'Puerto Rico'),
#   Text(-0.9193881124184582, -0.6039250770945224, 'Russia'),
#   Text(-0.8584734644924764, -0.6877669014733736, 'Spain'),
#   Text(-0.7899389451886549, -0.7655040580390383, 'Sweden'),
#   Text(-0.7655040950187486, -0.7899389093528226, 'Switzerland'),
#   Text(-0.727443072328198, -0.8251221585448499, 'Turkey'),
#   Text(-0.6877669441731687, -0.8584734302834897, 'United Arab Emirates'),
#   Text(-0.6182917407656086, -0.9097886146248665, 'United Kingdom'),
#   Text(0.5299290532444296, -0.96393734159823, 'United States'),
#   Text(1.0998642966458407, -0.017277990732430793, 'Uruguay')],
#  [Text(0.5999259794923052, 0.009424390176458191, '0%'),
#   Text(0.5993339250069523, 0.02826386979450656, '0%'),
#   Text(0.5787344524828968, 0.1583238248316459, '6%'),
#   Text(0.530259382751919, 0.2807578796820382, '0%'),
#   Text(0.5115841042993874, 0.3134991295493395, '1%'),
#   Text(0.47981080238620216, 0.36025212548090374, '1%'),
#   Text(0.4562435877968114, 0.38966881911989476, '0%'),
#   Text(0.4437786660136317, 0.4038074981859073, '0%'),
#   Text(0.39678713036083524, 0.45006663193355434, '3%'),
#   Text(0.3450031646119402, 0.49088982104719436, '0%'),
#   Text(0.2382887519098517, 0.5506527678249199, '6%'),
#   Text(0.06584060787261295, 0.59637657093062, '4%'),
#   Text(-0.009424369113036608, 0.5999259798231955, '0%'),
#   Text(-0.0376742898521586, 0.5988160384326187, '1%'),
#   Text(-0.07519991756668132, 0.5952688236401805, '1%'),
#   Text(-0.5428962235266768, 0.25546759183989, '31%'),
#   Text(-0.5115841061338816, -0.3134991265557169, '0%'),
#   Text(-0.5014844249555226, -0.329413678415194, '0%'),
#   Text(-0.46825825335953253, -0.3751455826218401, '3%'),
#   Text(-0.43087578828472084, -0.41754766802129356, '0%'),
#   Text(-0.41754768819204463, -0.4308757687379032, '0%'),
#   Text(-0.39678713036083524, -0.45006663193355445, '1%'),
#   Text(-0.37514560591263746, -0.4682582347000852, '0%'),
#   Text(-0.3372500404176046, -0.49624833524992706, '2%'),
#   Text(0.2890522108605979, -0.5257840045081253, '33%'),
#   Text(0.5999259799886404, -0.009424358581325886, '0%')])

# %%
clean_df.head()
# Out:
#    rank channel_info  influence_score  posts(k)  followers(m)  avg_likes(m)  \
# 0     1    cristiano               92      3.30         475.8           8.7
# 1     2  kyliejenner               91      6.90         366.2           8.3
# 2     3     leomessi               90      0.89         357.3           6.8
# 3     4  selenagomez               93      1.80         342.7           6.2
# 4     5      therock               91      6.80         334.1           1.9
#
#    60_day_eng_rate  new_post_avg_like(m)  total_likes(b)        country
# 0             1.39                   6.5            29.0          Spain
# 1             1.62                   5.9            57.4  United States
# 2             1.24                   4.4             6.0          Other
# 3             0.97                   3.3            11.5  United States
# 4             0.20                 665.3            12.5  United States

# %% [markdown]
# POST VS Other Columns

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(data=clean_df, x="posts(k)", y="influence_score")
# Out:
# <Axes: xlabel='posts(k)', ylabel='influence_score'>

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(data=clean_df, x="posts(k)", y="avg_likes(m)")
# Out:
# <Axes: xlabel='posts(k)', ylabel='avg_likes(m)'>

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(data=clean_df, x="posts(k)", y="total_likes(b)")
# Out:
# <Axes: xlabel='posts(k)', ylabel='total_likes(b)'>

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(data=clean_df, x="posts(k)", y="followers(m)")
# Out:
# <Axes: xlabel='posts(k)', ylabel='followers(m)'>

# %% [markdown]
# Follower VS Other Column

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(data=clean_df, x="followers(m)", y="influence_score")
# Out:
# <Axes: xlabel='followers(m)', ylabel='influence_score'>

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(data=clean_df, x="followers(m)", y="total_likes(b)")
# Out:
# <Axes: xlabel='followers(m)', ylabel='total_likes(b)'>

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(data=clean_df, x="followers(m)", y="avg_likes(m)")
# Out:
# <Axes: xlabel='followers(m)', ylabel='avg_likes(m)'>
